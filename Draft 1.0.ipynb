# %% [markdown]
# In general, if one is able to generate a highly predictive model which selects the right trades to execute, they would also be playing an important role in sending the market signals that push prices closer to “fair” values. That is, a better model will mean the market will be more efficient going forward. However, developing good models will be challenging for many reasons, including a very low signal-to-noise ratio, potential redundancy, strong feature correlation, and difficulty of coming up with a proper mathematical formulation.

# %%
import os
import pandas as pd
import numpy as np
import sklearn

# %%
os.chdir("C:/Users/Sul Najm/Desktop/Projects/Data Science/Jane_street_Competition/")

# %%
df_features = pd.read_csv('features.csv')

# %%
df_features
# Out:
#          feature  tag_0  tag_1  tag_2  tag_3  tag_4  tag_5  tag_6  tag_7  \
# 0      feature_0  False  False  False  False  False  False  False  False
# 1      feature_1  False  False  False  False  False  False   True   True
# 2      feature_2  False  False  False  False  False  False   True   True
# 3      feature_3  False  False  False  False  False  False   True  False
# 4      feature_4  False  False  False  False  False  False   True  False
# ..           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 125  feature_125  False  False  False   True  False  False  False  False
# 126  feature_126  False  False   True  False  False  False  False  False
# 127  feature_127  False  False   True  False  False  False  False  False
# 128  feature_128  False   True  False  False  False  False  False  False
# 129  feature_129  False   True  False  False  False  False  False  False
#
#      tag_8  ...  tag_19  tag_20  tag_21  tag_22  tag_23  tag_24  tag_25  \
# ...

# %%
df_features.shape
# Out:
# (130, 30)

# %%
df_train = pd.read_csv('train.csv')

# %%
df_train
# Out:
#          date     weight    resp_1    resp_2    resp_3    resp_4      resp  \
# 0           0   0.000000  0.009916  0.014079  0.008773  0.001390  0.006270
# 1           0  16.673515 -0.002828 -0.003226 -0.007319 -0.011114 -0.009792
# 2           0   0.000000  0.025134  0.027607  0.033406  0.034380  0.023970
# 3           0   0.000000 -0.004730 -0.003273 -0.000461 -0.000476 -0.003200
# 4           0   0.138531  0.001252  0.002165 -0.001215 -0.006219 -0.002604
# ...       ...        ...       ...       ...       ...       ...       ...
# 2390486   499   0.000000  0.000142  0.000142  0.005829  0.020342  0.015396
# 2390487   499   0.000000  0.000012  0.000012 -0.000935 -0.006326 -0.004718
# 2390488   499   0.000000  0.000499  0.000499  0.007605  0.024907  0.016591
# 2390489   499   0.283405 -0.000156 -0.000156 -0.001375 -0.003702 -0.002004
# 2390490   499   0.000000 -0.001855 -0.001855 -0.001194 -0.000864 -0.001905
#
# ...

# %%
df_train.shape
# Out:
# (2390491, 138)

# %%
df_example_test = pd.read_csv('example_test.csv')
df_example_test.head()
# Out:
#       weight  feature_0  feature_1  feature_2  feature_3  feature_4  \
# 0   0.000000          1  -1.872746  -2.191242  -0.474163  -0.323046
# 1  16.673515         -1  -1.349537  -1.704709   0.068058   0.028432
# 2   0.000000         -1   0.812780  -0.256156   0.806463   0.400221
# 3   0.000000         -1   1.174378   0.344640   0.066872   0.009357
# 4   0.138531          1  -3.172026  -3.093182  -0.161518  -0.128149
#
#    feature_5  feature_6  feature_7  feature_8  ...  feature_122  feature_123  \
# 0   0.014688  -0.002484        NaN        NaN  ...     1.168391     8.313583
# 1   0.193794   0.138212        NaN        NaN  ...    -1.178850     1.777472
# 2  -0.614188  -0.354800        NaN        NaN  ...     6.115747     9.667908
# 3  -1.006373  -0.676458        NaN        NaN  ...     2.838853     0.499251
# 4  -0.195006  -0.143780        NaN        NaN  ...     0.344850     4.101145
#
#    feature_124  feature_125  feature_126  feature_127  feature_128  \
# ...

# %%
df_example_sub = pd.read_csv('example_sample_submission.csv')
df_example_sub.head()
# Out:
#    ts_id  action
# 0      0       1
# 1      1       1
# 2      2       1
# 3      3       1
# 4      4       1

# %% [markdown]
# Baseline Model
# 1) Create general return rate for year to determine if action or non action
# 2) Run Model on Resp and all features
#
# Advanced Model
# 3) Determine which features from the feature set to use or not to use. (NAN, correlation matrix)
# 4) K cross Validation
# 5) Evaluate the use of the other time zones for resp
# 6) Determine risk threshold if possible
# 7) Run advanced Model

# %% [markdown]
# #### Baseline Model

# %%
df_train.head()
# Out:
#    date     weight    resp_1    resp_2    resp_3    resp_4      resp  \
# 0     0   0.000000  0.009916  0.014079  0.008773  0.001390  0.006270
# 1     0  16.673515 -0.002828 -0.003226 -0.007319 -0.011114 -0.009792
# 2     0   0.000000  0.025134  0.027607  0.033406  0.034380  0.023970
# 3     0   0.000000 -0.004730 -0.003273 -0.000461 -0.000476 -0.003200
# 4     0   0.138531  0.001252  0.002165 -0.001215 -0.006219 -0.002604
#
#    feature_0  feature_1  feature_2  ...  feature_121  feature_122  \
# 0          1  -1.872746  -2.191242  ...          NaN     1.168391
# 1         -1  -1.349537  -1.704709  ...          NaN    -1.178850
# 2         -1   0.812780  -0.256156  ...          NaN     6.115747
# 3         -1   1.174378   0.344640  ...          NaN     2.838853
# 4          1  -3.172026  -3.093182  ...          NaN     0.344850
#
#    feature_123  feature_124  feature_125  feature_126  feature_127  \
# 0     8.313583     1.782433    14.018213     2.653056    12.600292
# ...

# %%
df_baseline = df_train.drop(['resp_1', 'resp_2', 'resp_3', 'resp_4'], axis = 1)

# %%
df_baseline.loc[df_baseline.resp > 0, 'resp'] = 1
df_baseline.loc[df_baseline.resp == 0, 'resp'] = 'NA'
df_baseline.loc[df_baseline.resp < 0, 'resp'] = 0

# %%
df_baseline = df_baseline.rename(columns={"resp":"action"})

# %%
df_baseline.head()
# Out:
#    date     weight action  feature_0  feature_1  feature_2  feature_3  \
# 0     0   0.000000    1.0          1  -1.872746  -2.191242  -0.474163
# 1     0  16.673515      0         -1  -1.349537  -1.704709   0.068058
# 2     0   0.000000    1.0         -1   0.812780  -0.256156   0.806463
# 3     0   0.000000      0         -1   1.174378   0.344640   0.066872
# 4     0   0.138531      0          1  -3.172026  -3.093182  -0.161518
#
#    feature_4  feature_5  feature_6  ...  feature_121  feature_122  \
# 0  -0.323046   0.014688  -0.002484  ...          NaN     1.168391
# 1   0.028432   0.193794   0.138212  ...          NaN    -1.178850
# 2   0.400221  -0.614188  -0.354800  ...          NaN     6.115747
# 3   0.009357  -1.006373  -0.676458  ...          NaN     2.838853
# 4  -0.128149  -0.195006  -0.143780  ...          NaN     0.344850
#
#    feature_123  feature_124  feature_125  feature_126  feature_127  \
# 0     8.313583     1.782433    14.018213     2.653056    12.600292
# ...

# %%
cols_to_order = ['date','ts_id','action']
new_columns = (df_baseline.columns.drop(cols_to_order).tolist()) + cols_to_order 
df_baseline = df_baseline[new_columns]

# %%
df_baseline.isna().sum()
# Out:
# weight            0
# feature_0         0
# feature_1         0
# feature_2         0
# feature_3       448
#                ...
# feature_128    1921
# feature_129    1921
# date              0
# ts_id             0
# action            0
# Length: 134, dtype: int64

# %%
df_baseline.dropna()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-85-9491d5e9b3f6> in <module>
# ----> 1 df_baseline.dropna()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    5174                 raise TypeError("must specify how or thresh")
#    5175
# -> 5176         result = self.loc(axis=axis)[mask]
#    5177
#    5178         if inplace:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     892
#     893             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 894             return self._getitem_axis(maybe_callable, axis=axis)
#     895
#     896     def _is_scalar_access(self, key: Tuple):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
# ...

# %%
df_baseline.isna().sum()
# Out:
# weight            0
# feature_0         0
# feature_1         0
# feature_2         0
# feature_3       448
#                ...
# feature_128    1921
# feature_129    1921
# date              0
# ts_id             0
# action            0
# Length: 134, dtype: int64

# %%
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense

# %%
# split into input (X) and output (y) variables
X = df_baseline.iloc[:20000,1:131]

# %%
y = df_baseline.iloc[:20000,133:134]

# %%
print(y.shape)
print(X.shape)
# Out:
# (20000, 1)
# (20000, 130)

# %%
model = Sequential()

# %%
model.add(Dense(12, input_dim = 130, activation = 'relu' ))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=130, batch_size=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\data\util\structure.py in normalize_element(element)
#      92       try:
# ---> 93         spec = type_spec_from_value(t, use_fallback=False)
#      94       except TypeError:
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\data\util\structure.py in type_spec_from_value(element, use_fallback)
#     465   raise TypeError("Could not build a TypeSpec for %r with type %s" %
# --> 466                   (element, type(element).__name__))
#     467
#
# TypeError: Could not build a TypeSpec for       action
# 0        1.0
# 1          0
# 2        1.0
# 3          0
# 4          0
# ...      ...
# 19995    1.0
# 19996      0
# 19997    1.0
# 19998    1.0
# 19999    1.0
#
# [20000 rows x 1 columns] with type DataFrame
#
# ...
